# %%
import numpy as np

# %%
results = np.load("Resultados0_2.npz")["results"]
results2 = np.load("Resultados2_25.npz")["results"]
results3 = np.load("Resultados25_50.npz")["results"]
resultados = np.vstack((results, results2, results3))
np.savez("Resultados0_50.npz", results=resultados)
