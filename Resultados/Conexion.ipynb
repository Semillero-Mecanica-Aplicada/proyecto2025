# %%
import numpy as np

# %%
results = np.load("Resultados_periodicBC.npz")["results"]
results2 = np.load("Resultados.npz")["results"]
resultados = np.vstack((results, results2))
np.savez("Resultados0_2.npz", results=resultados)

# %%
resultados
# Out:
# array([[ 3.26779087e+09,  3.85665556e+09,  3.48284852e+09,
#          5.09211889e+08, -1.48779938e+08, -1.88423329e+08],
#        [ 2.45545907e+09,  2.69452666e+09,  1.18073540e+09,
#          1.21678750e+09,  2.35374853e+08,  2.30464164e+07],
#        [ 2.68982937e+09,  2.44126451e+09,  8.19019802e+08,
#          1.34331249e+09, -4.15422645e+08, -2.21146813e+08],
#        ...,
#        [ 2.48317912e+09,  2.50601046e+09,  6.45783754e+08,
#          1.34258549e+09, -3.52105273e+08, -2.64489896e+08],
#        [ 2.82816892e+09,  2.44690553e+09,  7.15819655e+08,
#          1.51532058e+09, -4.13198675e+08, -3.05292001e+08],
#        [ 2.59523726e+09,  2.11464345e+09,  7.15386470e+08,
#          1.25124221e+09, -2.70183497e+08, -1.05393191e+08]])
